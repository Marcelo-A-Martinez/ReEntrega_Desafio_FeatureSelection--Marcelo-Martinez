# %% [markdown]
# # **CURSO: DATA SCIENCE - CODERHOUSE**
# ### **DATASET:** CLÍNICA
# ### **AUTOR:** MARCELO ADRIÁN MARTINEZ

# %% [markdown]
# #### **ABSTRACTO**
# El presente informe está destinado a los responsables de la gestión de la Clínica Tiempo la cual cuenta con una larga trayectoria en la ciudad, siendo la más prestigiosa de la región.
# Ante la situación de la limitación de recursos con los que cuenta la clínica y con el fin de prever una compra de insumos y otros elementos de trabajo, los ejecutivos están buscando conocer cuál será la duración de la estancia de los pacientes en el clínica.
# Para ello, el director de la clínica nos facilita este dataset con datos recopilados sobre distintas cuestiones de los pacientes que han estado en la clínica.
# Los campos del dataset se refieren a distintos aspectos registrados de cada paciente.
# En base a ello y a las necesidades de información de los directivos, se realizará un modelo predictivo con el fin de establecer la duración de la estancia de los pacientes en la Clínica.

# %% [markdown]
# #### **OBJETIVOS**
# * Establecer la cantidad de pacientes que se recibirán el siguiente año.
# * Determinar los factores inciden en mayor medida en la duración de la estancia de los pacientes en la
# clínica.
# * Analizar la asignación de recursos en pos de ofrecer un excelente servicio.
# * Identificar caracteristicas que permitan agrupar a los pacientes según sus necesidades.

# %% [markdown]
# #### **CONTEXTO COMERCIAL**
# La Clínica tiene una amplia trayectoria en la ciudad, brindando servicios de excelencia a sus miles de
# pacientes que año tras año llegan a la misma. Esto la ha posicionado entre los demás centros de salud de
# la zona, tanto por su prestaciones de excelencia como también su constante inversión en equipos de alta
# tecnología.
# La Clínica ofrece distintos servicios, entre ellos están los de internación por diversas cuestiones de
# salud.
# En el último año la clínica tuvo 100.000 internaciones y la duración de dichas internaciones van
# de 1 (uno) a 17 (diecisiete) días.

# %% [markdown]
# #### **PROBLEMA COMERCIAL**
# En base a lo mencionado en los apartados anteriores el director de la Clínica, en pos de seguir ofreciendo
# a sus pacientes la mejor atención, quiere determinar la cantidad y la duración de las estancias de los
# pacientes con el fin de realizar una óptima asignación de los recursos con los que cuenta la Clínica.
#
# #### **PREGUNTAS**
#     * ¿Cuántos días van a durar las estancias de los pacientes en la clínica?
#     * ¿Cuál es la duración máxima de la estancia? ¿Y la mínima?
#     * ¿Qué factores inciden en mayor medida en la duración de la estancia?
#     * ¿Cuál será la cantidad de pacientes admitidos?
#     * ¿Existe alguna relación entre el género del paciente y la duración de la estancia?
# #### **HIPÓTESIS**
#     - El género del paciente incide en la duración de la estancia del mismo en la clínica.

# %% [markdown]
# #### **CONTEXTO ANALÍTICO**
# Para cumplir con los objetivos planteados y dar solución a la problemática, el director de la clínica nos facilita este dataset con datos recopilados sobre distintas cuestiones de los pacientes que han estado en la clínica. El mismo está estructurado en 28 columnas y 100.000 filas.
# Los campos del dataset se refieren a distintos aspectos registrados de cada paciente, entre las variables están:
# *   ID Admisión: un identificador por cada admisión de un paciente que se da en el hospital.
# *   FechaVisita: la fecha en la que se produjo la visita del paciente.
# *   NumReadmisiones: el número de readmisiones que se han dado.
# *   Género: 1 para mujeres y 0 para hombres.
# *   Renal: si tiene algún síntoma o problema de índole renal.
# *   Asma: si tiene algún síntoma o problema de asma.
# *   FaltaHierro: si tiene algún problema de falta de hierro o no.
# *   Neumonia: si tiene algún problema de neumonía o no.
# *   DependenciaSustancias: si tiene algún problema de dependencia de sustancias o no.
# *   DesordenPsicologico: si tiene algún problema de desórdenes psicológicos o no.
# *   Depresion: si tiene algún problema de depresión o no.
# *   OtrosDesordenesPsiquicos: si tiene algún problema de otros desórdenes psíquicos o no.
# *   Fibrosis: si tiene algún problema de fibrosis o no.
# *   Malnutricion: si tiene algún problema de malnutrición o no.
# *   DesordenSangre: si tiene algún problema de desorden en sangre o no.
# *   Sodio: si tiene algún síntoma o problema de sodio.
# *   Hematocrito: si tiene algún síntoma o problema de hematocrito.
# *   Neutrofilos: si tiene algún síntoma o problema de neutrófilos.
# *   Glucosa: si tiene algún síntoma o problema de glucosa.
# *   UreaSangre: si tiene algún síntoma o problema de urea en sangre.
# *   Creatinina: si tiene algún síntoma o problema de creatinina.
# *   BMI: el índice de masa corporal del paciente.
# *   Pulso: pulsaciones del paciente por minuto.
# *   Respiracion: la respiración del paciente cada 30 segundos.
# *   DiagnosticoSecundario: cuál es el diagnóstico secundario del paciente.
# *   FechaAlta: la fecha en la que se le ha dado de alta al paciente.
# *   IDHospital: el identificar de la sede del hospital donde ha sido ingresado.
# *   DuracionEstancia: los días que duró la estancia del paciente en la clínica.

# %% [markdown]
# ## **IMPORTACIÓN DE LOS PAQUETES**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from google.colab import files
from PIL  import Image
import requests
import missingno as msno
import json
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import r2_score
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb

# %% [markdown]
# ## **CARGA DEL DATASET "CLINICA"**

# %%
from posixpath import sep
url= "https://raw.githubusercontent.com/Marcelo-A-Martinez/DATASET_CLINICA/main/Clinica.csv"
Clinica= pd.read_csv(url, sep=';', decimal= ".", header=0)
Clinica.head()
# Out:
#    idAdmision fechaVisita  numReadmisiones  genero  renal  asma  faltaHierro  \
# 0           1   8/29/2012              0.0       1      0     0            0
# 1           3   9/22/2012              1.0       1      0     0            0
# 2           4    8/9/2012              0.0       1      0     0            0
# 3           5  12/20/2012              0.0       1      0     0            0
# 4           6  11/27/2012              3.0       0      0     0            0
#
#    neumonia  dependenciaSustancias  desordenPsicologico  ...     glucosa  \
# 0         0                      0                    0  ...  192.476918
# 1         0                      0                    0  ...  130.530524
# 2         0                      0                    0  ...  163.377028
# 3         1                      0                    1  ...   94.886654
# 4         0                      0                    0  ...  120.265259
#
#    ureaSangre  creatinina        bmi  pulso  respiracion  \
# 0        12.0    1.390722  30.432418     96          6.5
# 1        12.0    1.065750  28.843812     64          6.5
# 2        12.0    0.906862  27.959007     76          6.5
# 3        11.5    1.242854  30.258927     67          5.6
# 4        11.0    0.884663  27.875940     83          6.1
#
#    diagnosticoSecundario   fechaAlta  idHospital  duracionEstancia
# 0                      4    9/1/2012           B                 3
# 1                      2   9/25/2012           B                 3
# 2                      1   8/10/2012           A                 1
# 3                      2  12/24/2012           E                 4
# 4                      1   12/3/2012           B                 6
#
# [5 rows x 28 columns]

# %%
Clinica1= Clinica.drop(['idAdmision','fechaVisita', 'fechaAlta', 'idHospital' , 'numReadmisiones', 'asma', 'neumonia' ,
'dependenciaSustancias' , 'depresion' , 'fibrosis' , 'hematocrito' , 'neutrofilos', 'sodio' , 'glucosa' , 'ureaSangre' ,
'creatinina' , 'bmi' , 'pulso' , 'respiracion' , 'diagnosticoSecundario' , 'renal' , 'genero', 'malnutricion'], axis=1)

# %% [markdown]
# ## **ANÁLISIS DEL CONJUNTO DE DATOS**

# %% [markdown]
# #### **PRINCIPALES ESTADÍSTICAS**

# %%
Clinica1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95013 entries, 0 to 95012
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   faltaHierro               95013 non-null  int64
#  1   desordenPsicologico       95013 non-null  int64
#  2   otrosDesordenesPsiquicos  95013 non-null  int64
#  3   desordenSangre            95013 non-null  int64
#  4   duracionEstancia          95013 non-null  int64
# dtypes: int64(5)
# memory usage: 3.6 MB

# %%
Clinica1.describe()
# Out:
#         faltaHierro  desordenPsicologico  otrosDesordenesPsiquicos  \
# count  95013.000000         95013.000000              95013.000000
# mean       0.095092             0.239062                  0.049330
# std        0.293344             0.426513                  0.216557
# min        0.000000             0.000000                  0.000000
# 25%        0.000000             0.000000                  0.000000
# 50%        0.000000             0.000000                  0.000000
# 75%        0.000000             0.000000                  0.000000
# max        1.000000             1.000000                  1.000000
#
#        desordenSangre  duracionEstancia
# count    95013.000000       95013.00000
# mean         0.080168           3.77601
# std          0.271555           2.18028
# min          0.000000           1.00000
# 25%          0.000000           2.00000
# 50%          0.000000           4.00000
# 75%          0.000000           5.00000
# max          1.000000          17.00000

# %%
# Análisis de varibles con mayor correlación con relación a la varibale objetivo "duraciónEstancia":
cor=Clinica1.corr()
cortarget=abs(cor["duracionEstancia"])
Var_Destacadas= cortarget[cortarget>=0.20]
print(Var_Destacadas)
# Out:
# faltaHierro                 0.214208
# desordenPsicologico         0.315288
# otrosDesordenesPsiquicos    0.209112
# desordenSangre              0.240024
# duracionEstancia            1.000000
# Name: duracionEstancia, dtype: float64

# %% [markdown]
# Llevado adelante el análisis de correlatividad, se determinó que las existen 4 variables que tienen mayor grado de correlación con respecto a la variable objetivo "duraciónEstancia".

# %% [markdown]
# # **MODELO DE MACHINE LEARNING**

# %% [markdown]
# ### **ÁRBOLES DE REGRESIÓN**

# %%
#X=Clinica1.iloc[:, 0:7]
#X=X.reshape(1,-1)
#y=Clinica1.iloc[:, 7]
#y=y.reshape(1,-1)

X = Clinica1.drop(['duracionEstancia'], axis=1)
y = Clinica1['duracionEstancia']

# Verificar las dimensiones
print(X.shape)  # Dimensiones de X
print(y.shape) # Dimensiones de y
# Out:
# (95013, 4)
# (95013,)

# %%
# DIVISIÓN ENTRE DATOS DE ENTRENAMIENTO Y TEST:
X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y,
                                        test_size=0.30,
                                        random_state = 0
                                    )

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (66509, 4)
# (28504, 4)
# (66509,)
# (28504,)

# %%
# CREACIÓN DEL MODELO
# ---------------------------------------------------------------------------------------------------------
modelo = DecisionTreeRegressor(max_depth=3)

# ENTRENAMIENTO DEL MODELO
modelo = modelo.fit(X_train, y_train)

# VISUALIZACIÓN DEL ENTRENAMIENTO DEL MODELO
fig = plt.figure(figsize=(20, 18))

tree.plot_tree(modelo, feature_names= list(X.columns.values),
                        class_names=list(y.values), filled=True)

plt.show()

# %%
# PREDICCIONES
y_train_pred = modelo.predict(X_train)
y_train_pred
# Out:
# array([3.12433146, 3.12433146, 3.12433146, ..., 3.12433146, 3.12433146,
#        3.12433146])

# %%
y_test_pred = modelo.predict(X_test)
y_test_pred
# Out:
# array([4.83601141, 3.12433146, 3.12433146, ..., 3.12433146, 4.83601141,
#        3.12433146])

# %%
# Comparamos con las etiquetas reales
print('Error en datos de train:', mean_squared_error(y_train_pred,y_train))
print('Error en datos de test:', mean_squared_error(y_test_pred,y_test))
print('Score en datos de train:', modelo.score(X_train, y_train)*100)
print('Score en datos de test:', modelo.score(X_test, y_test)*100)

ad_test_mse = mean_squared_error(y_train, y_train_pred)
ad_train_mse = mean_squared_error(y_test, y_test_pred)
# Out:
# Error en datos de train: 3.863310276253489
# Error en datos de test: 3.9063393040680148
# Score en datos de train: 18.46168416449303
# Score en datos de test: 18.444514965795022

# %% [markdown]
# ### **RANDOM FOREST**

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                        Clinica1.drop(columns = "duracionEstancia"),
                                        Clinica1['duracionEstancia'],
                                        random_state = 123
                                    )

# Creación del modelo
# ==============================================================================
modelo = RandomForestRegressor(
            n_estimators = 200,
            criterion    = "squared_error",
            max_depth    = 6,
            max_features = 'sqrt',
            oob_score    = True,
            n_jobs       = -1,
            random_state = 123
         )

# %%
# Entrenamiento del modelo
# ==============================================================================
modelo.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=6, max_features='sqrt', n_estimators=200,
#                       n_jobs=-1, oob_score=True, random_state=123)

# %%
# Predicciones
# ==============================================================================
predic_y_train = modelo.predict(X_train)
predic_y_test  = modelo.predict(X_test)

# %%
# Error de test del modelo inicial
# ==============================================================================

print('Error en datos de train:', mean_squared_error(predic_y_train, y_train))
print('Error en datos de test:', mean_squared_error(predic_y_test,y_test))
print('Score en datos de train:', modelo.score(X_train, y_train)*100)
print('Score en datos de test:', modelo.score(X_test, y_test)*100)

rfr_test_mse = mean_squared_error(y_train, predic_y_train)
rfr_train_mse = mean_squared_error(y_test, predic_y_test)
# Out:
# Error en datos de train: 3.8141210144692863
# Error en datos de test: 3.7760802468723917
# Score en datos de train: 19.928551966350483
# Score en datos de test: 20.06276658322551

# %% [markdown]
# ### **KNeighbors Regression**

# %%
# Obtener datos de entrada
#X = Clinica1.drop(['duracionEstancia'], axis=1)
y = Clinica1['duracionEstancia']

# Verificar las dimensiones
print(X.shape)  # Dimensiones de X
print(y.shape)  # Dimensiones de y
# Out:
# (95013, 4)
# (95013,)

# %%
# División entre datos de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.30, random_state=0, stratify=y)

# Crear y ajustar el modelo de KNeighborsRegressor
modelo = KNeighborsRegressor(n_neighbors=3)
modelo.fit(X_train, y_train)

# Realizar predicciones
predic_y_train = modelo.predict(X_train)
predic_y_test = modelo.predict(X_test)

# Graficar los resultados
plt.figure(figsize=(10, 8))
sns.set_theme()

# Datos de entrenamiento
#plt.scatter(X_train.iloc[:, 0], y_train, color='green', alpha=0.2, label='Datos Train')
#plt.scatter(X_train.iloc[:, 0], predic_y_train, color='black', linewidth=1.0, linestyle='--', label='Predicción Train')
plt.scatter(X_train, y_train, color='green', alpha=0.2, label='Datos Train')
plt.scatter(X_train, predic_y_train, color='black', linewidth=1.0, linestyle='--', label='Predicción Train')

# Datos de prueba
#plt.scatter(X_test.iloc[:, 0], y_test, color='red', linewidth=1.0, alpha=0.2, label='Datos Test')
#plt.scatter(X_test.iloc[:, 0], predic_y_test, color='blue', linewidth=1.0, label='Predicción Test')
plt.scatter(X_test, y_test, color='red', linewidth=1.0, alpha=0.2, label='Datos Test')
plt.scatter(X_test, predic_y_test, color='blue', linewidth=1.0, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes")

plt.legend()
plt.show()

kns_test_mse = mean_squared_error(y_train, predic_y_train)
kns_train_mse = mean_squared_error(y_test, predic_y_test)

# %% [markdown]
# ## **XG-Boost Regression**

# %%
# Obtener datos de entrada
#X = Clinica1.drop(['duracionEstancia'], axis=1)
#X = Clinica1['otrosDesordenesPsiquicos']
y = Clinica1['duracionEstancia']
# División entre datos de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.30, random_state=0, stratify=y)

# %%
modelo = xgb.XGBRegressor(n_estimators=100, random_state=42)
modelo.fit(X_pca, y)
predic_y_train = modelo.predict(X_train)
predic_y_test  = modelo.predict(X_test)
plt.figure(figsize = (10,8))
sns.set_theme()

# Datos de entrenamiento
#plt.scatter(X_train.iloc[:, 0], y_train, color='green', alpha=0.1, label='Datos Train')
#plt.scatter(X_train.iloc[:, 0], predic_y_train, color='black', linewidth=1.5, label='Predicción Train')
plt.scatter(X_train, y_train, color='green', alpha=0.1, label='Datos Train')
plt.scatter(X_train, predic_y_train, color='black', linewidth=1.5, label='Predicción Train')

# Datos de prueba
#plt.scatter(X_test.iloc[:, 0], y_test, color='red', alpha=0.1, label='Datos Test')
#plt.scatter(X_test.iloc[:, 0], predic_y_test, color='blue', linewidth=1.5, label='Predicción Test')
plt.scatter(X_test, y_test, color='red', alpha=0.1, label='Datos Test')
plt.scatter(X_test, predic_y_test, color='blue', linewidth=1.5, label='Predicción Test')

plt.xlabel("Longitud de Rama Horizontal (LRH)")
plt.ylabel("Duración Estancia de los Pacientes")
plt.title("Predicción Duración Estancia de los Pacientes")



plt.legend()
plt.show()

print('Error en datos de train:', mean_squared_error(y_train, predic_y_train))
print('Error en datos de test:', mean_squared_error(y_test, predic_y_test))

xgb_test_mse = mean_squared_error(y_train, predic_y_train)
xgb_train_mse = mean_squared_error(y_test, predic_y_test)
# Out:
# Error en datos de train: 3.8133244877553487
# Error en datos de test: 3.7833846117784913

# %% [markdown]
# ## **COMPARACIÓN DE LOS MODELOS**

# %%
valores = [kns_train_mse, rfr_train_mse, xgb_train_mse]

nombres = ['Kns', 'Forest', 'XGB']

plt.figure(figsize=(10, 6))
plt.bar(nombres, valores, color='blue')

plt.xlabel('Modelo')
plt.ylabel('MSE Train')
plt.title('Comparación de MSE entre modelos')

for i, value in enumerate(valores):
    plt.text(i, value, str(round(value, 2)), ha='center', va='bottom')

plt.show()

# %% [markdown]
# A partir de los resultados arrojados por los distintos modelos utilizados y basándonos en el error cuádratico medio (MSE) los modelos que Forest y XGB presentan el mismo error y a su vez es el menor, ya que KNS presenta un error mayor. De esta manera, los dos modelos que presentan mejor precisión aon Forest y XGB.

# %% [markdown]
# **MÉTRICAS**

# %%
#

mse = mean_squared_error(y_test, predic_y_test)
print("MSE:", mse)
#--------------------------------------------------
rmse = np.sqrt(mse)
print("RMSE:", rmse)
#--------------------------------------------------
mae = MAE(y_test, predic_y_test)
print("MAE:", mae)
#--------------------------------------------------
r2 = r2_score(y_test, predic_y_test)
print("R^2:", r2)
# Out:
# MSE: 3.7833846117784913
# RMSE: 1.945092442990433
# MAE: 1.5968906199651054
# R^2: 0.20317517395780227

# %% [markdown]
# ## **PCA**

# %%
#-------------------------------------------------------------------------------
X = Clinica1.drop('duracionEstancia', axis=1)
y = Clinica1['duracionEstancia']

#---------------- NORMALIZACIÓN DE VARIABLES------------------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

#---------------- REDUCCIÓN DE DIMENSIONALIDAD ---------------------------------
pca = PCA(n_components=1)
X_pca = pca.fit_transform(X_scaled)

#---------------- VARIANZA DE CADA COMPONENTE ----------------------------------
explained_variance = pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [0.35140185]

# %%
print(X_pca)
# Out:
# [[-0.66355905]
#  [-0.66355905]
#  [-0.66355905]
#  ...
#  [ 1.13422602]
#  [-0.66355905]
#  [-0.66355905]]

# %%
plt.bar(range(len(explained_variance)), explained_variance)
plt.xlabel('Componente Principal')
plt.ylabel('Proporción de Varianza Explicada')
plt.title('Varianza Explicada por Componente Principal')
plt.show()

# %%
# Después de aplicar PCA
principal_components = pca.fit_transform(X_scaled)

# Componentes principales
components = pca.components_

# Visualización de los componentes
components_df = pd.DataFrame(data=components, columns=X.columns)
components_df
# Out:
#    faltaHierro  desordenPsicologico  otrosDesordenesPsiquicos  desordenSangre
# 0     0.527366             0.382805                  0.565686        0.505316

# %% [markdown]
# ## **HIPERPARÁMETROS**

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, learning_curve
from sklearn.metrics import r2_score

#Cantidad óptima de clústers seleccionada
cv = 6

# Función de pérdida a optimizar
loss = ["ls", "lad", "huber"]

# Profundidad máxima de cada árbol
max_depth = [2, 3, 5, 10, 15]

# Número mínimo de muestras por hoja
min_samples_leaf = [1, 2, 4, 6, 8]

# Número mínimo de muestras para dividir un nodo
min_samples_split = [1, 2, 4, 6, 10]

# Número máximo de características a considerar para hacer divisiones
max_features = ["auto", "sqrt", "log2", None]

hyperparameter_grid = {"loss": loss,
                       "max_depth": max_depth,
                       "min_samples_leaf": min_samples_leaf,
                       "min_samples_split": min_samples_split,
                       "max_features": max_features}

trees_grid = {"n_estimators": [50, 100, 150, 200, 250, 300]}

# %%
#Random Forest

n_estimators = [50,100,250,300]

hyperparameters = dict(n_estimators=n_estimators)

random_forest_model = RandomForestRegressor(random_state=60)

rf_grid_search = GridSearchCV(estimator=random_forest_model, param_grid=hyperparameters, cv=cv,
                           scoring="neg_mean_absolute_error", verbose=1,
                           n_jobs=-1, return_train_score=True)

rf_grid_search.fit(X_train, y_train)

rf_final_model = rf_grid_search.best_estimator_

print("\n Rendimiento del modelo de bosque aleatorio en el conjunto de prueba: R2 = {:.04f}".format(r2_score(y_test,rf_final_model.predict(X_test))))
# Out:
# Fitting 6 folds for each of 4 candidates, totalling 24 fits
#
#  Rendimiento del modelo de bosque aleatorio en el conjunto de prueba: R2 = 0.2029

# %% [markdown]
# ### **K-nearest Neighbour**

# %%
leaf_size = [1, 5]
n_neighbors = [1, 5]


hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=[1, 2])



knn_model = KNeighborsRegressor(n_neighbors=6)

knn_grid_search = GridSearchCV(estimator=knn_model, param_grid=hyperparameters, cv=5,
                           scoring="neg_mean_absolute_error", verbose=1,
                           n_jobs=-1, return_train_score=True)

knn_grid_search.fit(X_train, y_train)

knn_final_model = knn_grid_search.best_estimator_

print("\n Rendimiento del modelo K-Neighbors en el conjunto de prueba: R2 = {:.04f}".format(r2_score(y_test,knn_final_model.predict(X_test))))
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
#
#  Rendimiento del modelo K-Neighbors en el conjunto de prueba: R2 = 0.1718

# %% [markdown]
# Entre los dos modelos evaluados, el Ramdom Forest obtuvo un mejor rendimiento en compración con el K-nearest Neighbour, siendo que el primero obtuvo un r2 de 0.20 y el KNN un r2 de 0.17.

# %% [markdown]
# ## **CURVAS DE ENTRENAMIENTO**

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 50)):
    """Genere un gráfico simple de la prueba y la curva de aprendizaje del entrenamiento"""
    plt.figure(figsize=(15,8))
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Ejemplos de entrenamiento")
    plt.ylabel("Puntaje")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Puntaje de entrenamiento")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Puntuación de validación cruzada")

    plt.legend(loc="best")
    return plt

g = plot_learning_curve(knn_grid_search.best_estimator_,"\n Curvas de aprendizaje de K-Neighbors",X_train,y_train,cv=cv)
g = plot_learning_curve(rf_grid_search.best_estimator_,"\n Curvas de aprendizaje de Random Forest",X_train,y_train,cv=cv)
